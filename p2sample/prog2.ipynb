# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("xyz_data.csv")
X = data['X']
Y = data['Y']
Z = data['Z'] # This variable is defined but not used in the plot
plt.scatter(X, Y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatter Plot')
plt.show() # This line ensures the plot is displayed

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("xyz_data.csv")
X = data['X']
Y = data['Y']
Z = data['Z']

fig, ax1 = plt.subplots()

ax1.scatter(X, Y, color='blue', alpha=0.6)
ax1.set_title("2D Scatter Plot")
ax1.set_xlabel("X-axis")
ax1.set_ylabel("Y-axis")

plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv("xyz_data.csv")
X = data['X']
Y = data['Y']
Z = data['Z']
fig = plt.figure() 
ax3d = fig.add_subplot(projection='3d')
ax3d.scatter(X, Y, Z, c='orange', alpha=0.6)
ax3d.set_title("3D Scatter Plot")
ax3d.set_xlabel("X-axis")
ax3d.set_ylabel("Y-axis")
ax3d.set_zlabel("Z-axis")

plt.tight_layout()
plt.show()

# %%
sns.boxplot(data=data)
plt.title('Box Plot')
# Out:
# Text(0.5, 1.0, 'Box Plot')

# %%
sns.heatmap(data.corr(),annot=True,cmap='coolwarm')
plt.title('Heat Map')
# Out:
# Text(0.5, 1.0, 'Heat Map')

# %%
plt.tricontour(X,Y,Z,cmap='jet')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Contour Plot')
# Out:
# Text(0.5, 1.0, 'Contour Plot')

# %%
ax = plt.axes(projection="3d")
ax.plot_trisurf(X,Y,Z,cmap='jet_r')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('3D Surface Plot')
# Out:
# Text(0.5, 0.92, '3D Surface Plot')
